# %%
#Accept two numbers and find out with is greater

a =  int(input("Enter the number: "))
b = int(input("Enter the number: "))

if a>b:
         print(f"{a} is greater than {b}")
else:
    print(f"{b} is greater than {a}")
# Out:
# Enter the number:  20
# Enter the number:  40
# 40 is greater than 20

# %%
#Accept the number and print even or odd

num = int(input("Enter the number: "))

if num%2 == 0:
          print("Even number")
else:
          print("Odd number")
# Out:
# Enter the number:  20
# Even number

# %%
#Accept name and age from user and check eligibiliy for voting

Name = input("Enter the Name: ")
Age = int(input("Enter the age: "))

if Age >= 18:
      print(f"{Name} you are able to vote")
else:
      print(f"{Name} you are not able to vote")
# Out:
# Enter the Name:  Om
# Enter the age:  18
# Om you are able to vote

# %%
#check given year is leap year or not

year = int(input("Enter the year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is leap year")

else:
    print(f"{year} is not leap year")
# Out:
# Enter the year:  1900
# 1900 is not leap year

# %%
#Check the weather
a = int(input("Enter the tempurature: "))

if a < 0:
    print("Freezing cold")
elif a >= 0 or a <= 10:
    print("Very Cold")
elif a >= 11 or a <= 20:
    print("Cold")
elif a >= 21 or a<= 30:
    print("Pleasant")
else:
    print("Hot")
# Out:
# Enter the tempurature:  -10
# Freezing cold
